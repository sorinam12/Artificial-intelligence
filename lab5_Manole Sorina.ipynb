# %%
import numpy as np 
w=[[45, 45],[100, 45],[200, 45]] 
x=[[45, 85],[50, 43],[40, 80],[55,42],[200, 43],[48, 40],[195,41],[43, 87],[190, 40]] 
c=1 
epoca=0 
while epoca<100: 
    epoca=epoca+1 
    print("Epoca:", epoca) 
    for i in range(9): 
        w_min=[0,0,0] 
        print("[",x[i][0], x[i][1],"]") 
        w_min[0]=np.sqrt((x[i][0]-w[0][0])*(x[i][0]-w[0][0])+(x[i][1]-w[0][1])*(x[i][1]-w[0][1])) 
        w_min[1]=np.sqrt((x[i][0]-w[1][0])*(x[i][0]-w[1][0])+(x[i][1]-w[1][1])*(x[i][1]-w[1][1])) 
        w_min[2]=np.sqrt((x[i][0]-w[2][0])*(x[i][0]-w[2][0])+(x[i][1]-w[2][1])*(x[i][1]-w[2][1])) 
        min=np.min(w_min) 
        for j in range(3): 
            for p in range(2): 
                if w_min[j]==min:
                    w[j][p]=w[j][p]+c*(x[j][p]-w[j][p]) 
                print("Prototipul castigator:", w[j][p]) 
            break
# Out:
# Epoca: 1
# [ 45 85 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 50 43 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 40 80 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 55 42 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 200 43 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 48 40 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 195 41 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 43 87 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 190 40 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# Epoca: 2
# [ 45 85 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 50 43 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 40 80 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 55 42 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 200 43 ]
# Prototipul castigator: 45
# Prototipul castigator: 85
# [ 48 40 ]
# ...
